# %% [markdown]
# <a href="https://colab.research.google.com/github/NNAIZ/-My-Best-Projects-/blob/main/Assig_line_scatter_plt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# plt is athe alias name for pyplot
import numpy as np
# np is the alias for numpy
import pandas as pd
# pd is the alias for pandas

import warnings
warnings.filterwarnings("ignore")

# %%
web =pd.read_csv('/content/sample_data/DataScience_Marks_Dataset (4).csv')
web.head()
# Out:
#      Name  Python  SQL  Statistics  Total_marks
# 0    Amit      96   90          93          279
# 1    Arun      90   92          89          271
# 2  Ramesh      91   91          99          281
# 3   Vijay      98   92          92          282
# 4  Shreya      92   98          94          284

# %%
plt.plot(web['Name'],web['Total_marks'])

# %%
web['Name']=web['Name'].astype(float)
web['Name']=web['Name'].astype(int)
neet=web.set_index('Python')
neet

# %% [markdown]
# Create a Line plot of 'Name' vs 'SQL’ and apply the Following
# customization to the plot.
# ● Make the Figure size (9,4)
# ● Make line/markers color 'indigo'
# ● Make line width as 2 and line style as '-.'
# ● Add label as python
# ● Add markers as 'o' with markersize = 10
# ● Add a title to the Plot with fontsize = 15 and color = purple
# ● Add X-Label as Name & Y-Label as Python
# ● Add Grid to the plot using grid() function
# ● Show the legend for the plot using legend() funct
# ● Also Show the plot

# %%
plt.figure(figsize=(9,4))
plt.plot(neet.index,neet['Name'],neet['Python'],color='indigo',marker='o',label='Python',markersize=10,lw=2,linestyle='-')
plt.xlabel('Name')
plt.ylabel('Python')
plt.legend()
plt.title('N_S',fontsize=15,color='Purple')
plt.grid()
plt.show()

# %%
web['Name']=web['Name'].astype(float)
web['Name']=web['Name'].astype(int)
neet=web.set_index('Name')
neet

# %%
web['Name']=web['Name'].astype(float)
web['Name']=web['Name'].astype(int)
neet1=web.set_index('Name')
neet1
# Out:
#       Python  SQL  Statistics  Total_marks
# Name
# 90        96   90          93          279
# 92        90   92          89          271
# 91        91   91          99          281
# 92        98   92          92          282
# 98        92   98          94          284
# 95        95   95          92          282
# 93        97   93          90          280
# 99        89   99          98          286

# %%
web['Name']=web['Name'].astype(float)
web['Name']=web['Name'].astype(int)
neet2=web.set_index('Name')
neet2
# Out:
#       Python  SQL  Statistics  Total_marks
# Name
# 90        96   90          93          279
# 92        90   92          89          271
# 91        91   91          99          281
# 92        98   92          92          282
# 98        92   98          94          284
# 95        95   95          92          282
# 93        97   93          90          280
# 99        89   99          98          286

# %%
meta['BO_Collection']=meta['BO_Collection'].astype(float)
meta['BO_Collection']=meta['BO_Collection'].astype(int)
meta['Budget']=df1['Budget'].astype(int)
top_5=meta.nlargest(n=5,columns=['BO_Collection'])
top_5=top_5.set_index('Movie_Name')
top_5

# %% [markdown]
# Create a Line plot of 'Name' vs 'Python', 'Statistics' and 'SQL
# 'and apply the Following customization to the plot.
# ● Make the Figure size (9,4)
# ● Make the line of 'Name' vs 'Python' with color = 'cyan',
# marker = '^', label ='Python', markersize = 10
# ● Make the line of 'Name' vs 'Statistics' with color = 'red',
# marker = 'o', label ='Statistics', markersize = 10
# ● Make the line of 'Name' vs 'SQL' with color = 'purple',
# marker = '*', label ='SQL', markersize = 10
# ● Add a title to the Plot with fontsize = 13 and color = 'Blue'
# ● Add X-Label as Name
# ● Add Grid to the plot using grid() function
# ● Show the legend for the plot using legend() function
# ● Also Show the plot

# %%
plt.figure(figsize=(9,4))
plt.plot(neet.index,neet['Name'],neet['Python'],color='cyan',marker='^',label='Python',markersize=10)
plt.plot(neet1.index,neet['Name'],neet1['Statistics'],color='red',marker='o',label='Statistics',markersize=10)
plt.plot(neet2.index,neet['Name'],neet2['SQL'],color='Purple',marker='*',label='SQL',markersize=10)
plt.title('student_Data',fontsize=13,color='Blue')
plt.xlabel('Name')
plt.ylabel('Data')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Create a Scatter plot of Python vs Total marks and apply the
# Following customization to the plot.
# ● Make the Figure size (9,4)
# ● Make the scatter plot with marker = 'h', s='40' and color =
# 'Orange'
# ● Add X-Label as Python & Y-Label as Total_marks
# ● Add a title to the Plot with fontsize = 15 and color =
# 'purple'
# ● Add Grid to the plot using grid() function
# ● Also Show the plot

# %%
plt.figure(figsize=(9,4))
plt.scatter(data['Python'],data['Total_marks'],marker='h',s=40,color='Orange')
plt.xlabel('Python')
plt.ylabel('Total_marks')
plt.title('MY_data',fontsize=15,color='Purple')
plt.grid()
plt.show()

# %% [markdown]
# Create a Scatter plot of 'Name vs Python, Statistics and SQL' in
# the same plot and apply the Following customization to the
# plot.
# ● Make the Figure size (9,4)
# ● Make a scatter plot of 'Name' vs 'Python' with color =
# 'teal', marker = 's', s = 45, label='Name vs Python'
# ● Make a scatter plot of 'Name' vs 'Statistics' with color =
# 'salmon', marker = 'p', s = 45, label='Name vs Statistics'
# ● Make a scatter plot of 'Name' vs 'SQL' with color = 'orchid',
# marker = 'h', s = 45, label='Name vs SQL'
# ● Add a title to the Plot with fontsize = 15 and color = 'black'
# ● Add X-Label as Name
# ● Add Grid to the plot using grid() function
# ● Show the legend for the plot using legend() function
# ● Also Show the plot

# %%
plt.figure(figsize=(9,4))
plt.scatter(web['Name'],web['Python'],marker='s',s=45,color='teal',label='Name as Python')
plt.scatter(web['Name'],web['Statistics'],marker='p',s=45,color='salmon',label='Name as Statistics')
plt.scatter(web['Name'],web['SQL'],marker='h',s=45,color='orchid',label='Name as SQL')
plt.xlabel('Python')
plt.ylabel('Total_marks')
plt.title('My_data',fontsize=15,color='black')
plt.legend()
plt.grid()
